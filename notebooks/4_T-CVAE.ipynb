# %%
# %load_ext autoreload
# %autoreload 2
import copy
from dgl import batch, unbatch
import rdkit.Chem as Chem
from rdkit import RDLogger
import torch
torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
from pathlib import Path

import numpy as np
np.random.seed(0)

import os,sys,inspect
sys.path.insert(0,'/home/icarus/app/src') 

from models.jtnn_vae import DGLJTNNVAE
from models.modules import *

#from .nnutils import cuda, move_dgl_to_cuda

#from .jtnn_enc import DGLJTNNEncoder
#from .jtnn_dec import DGLJTNNDecoder
#from .mpn import DGLMPN
#from .mpn import mol2dgl_single as mol2dgl_enc
#from .jtmpn import DGLJTMPN
#from .jtmpn import mol2dgl_single as mol2dgl_dec

import os,sys,inspect
from tqdm import tqdm
sys.path.insert(0,'/home/icarus/T-CVAE-MolGen/src')


from utils.chem import set_atommap, copy_edit_mol, enum_assemble_nx, \
                            attach_mols_nx, decode_stereo

lg = RDLogger.logger()

lg.setLevel(RDLogger.CRITICAL)
# Out:
# RDKit WARNING: [18:47:35] Enabling RDKit 2019.09.1 jupyter extensions

# %%
class TCVAE(nn.Module):
    def __init__(self, vocab, hidden_size, latent_size, depth):
        super(TCVAE, self).__init__()
        self.vocab = vocab
        self.hidden_size = hidden_size
        self.latent_size = latent_size
        self.depth = depth
        
        self.embedding = nn.Embedding(vocab.size(), hidden_size).cuda()
        self.mpn = MPN(hidden_size, depth)
        self.encoder = None  #
        self.decoder = None  #
        
        self.T_mean, self.T_var = nn.Linear(hidden_size, latent_size // 2), \
                                  nn.Linear(hidden_size, latent_size // 2)
        self.G_mean, self.G_var = nn.Linear(hidden_size, latent_size // 2), \
                                  nn.Linear(hidden_size, latent_size // 2)
            
        self.n_nodes_total = 0
        self.n_edges_total = 0
        self.n_passes = 0

# %% [markdown]
# ## Posterior
#
# As in <cite data-cite="7333468/6Y976JUQ"></cite>
#
# $q(z|x,y) \sim N(\mu,\sigma^2I)$, where
#
# $\quad\quad h = \text{MultiHead}(c,E_\text{out}^L(x;y),E_\text{out}^L(x;y))$
#
# $\quad\quad \begin{bmatrix}\mu\\\log(\sigma^2)\end{bmatrix} = hW_q+b_q$

# %%
    def sample_posterior(self, prob_decode=False):
        return

# %% [markdown]
# ### Prior
#
# As in <cite data-cite="7333468/6Y976JUQ"></cite>
#
# $p_\theta (z|x) \sim N(\mu', \sigma'^2 I)$, where:
#
# $\quad\quad h' = \text{MultiHead}(c, E_\text{out}^L(x), E_\text{out}^L(x))$
#
# $\quad\quad \begin{bmatrix}\mu'\\\log(\sigma'^2)\end{bmatrix} = MLP_p(h')$

# %%
    def sample_prior(self, prob_decode=False):
        return

# %%
from utils.data import JTNNDataset, JTNNCollator
#torch.multiprocessing.set_sharing_strategy('file_system')
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

class ArgsTemp():
    def __init__(self, hidden_size, depth, device):
        self.hidden_size = hidden_size
        self.batch_size = 200
        self.latent_size = 56
        self.depth = depth
        self.device = device
        self.lr = 1e-3
        self.beta = 1.0
        self.use_cuda = torch.cuda.is_available()
        
args = ArgsTemp(200,3, device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
print(args.depth)

from pathlib import Path
data_path = Path('/home/icarus/app/data/01_raw/moses/tinytrain.csv')
vocab_path = Path('/home/icarus/app/data/03_processed/tinytrainvocab.txt')

dataset = JTNNDataset(data=data_path, 
                      vocab=vocab_path, training=True, intermediates=False)
vocab = dataset.vocab
"""
dataloader = DataLoader(
        dataset,
        batch_size=args.batch_size,
        shuffle=True,
        num_workers=1,
        collate_fn=JTNNCollator(vocab, True, intermediates=False),
        drop_last=True,
        worker_init_fn=None)
        """

model = DGLJTNNVAE(vocab, args.hidden_size, args.latent_size, args.depth, args).cuda()
model.share_memory()

model_path = None
if model_path is not None:
    model.load_state_dict(torch.load(model_path))
else:
    for param in model.parameters():
        if param.dim() == 1:
            nn.init.constant_(param, 0)
        else:
            nn.init.xavier_normal_(param)
#if torch.cuda.device_count() > 1:
  #print("Let's use", torch.cuda.device_count(), "GPUs!")
  # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
  #model = nn.DataParallel(model)
optimizer = optim.Adam(model.parameters(), lr=args.lr)
scheduler = lr_scheduler.ExponentialLR(optimizer, 0.9)
# Out:
# 3
# Loading data...
# <class 'pathlib.PosixPath'>
# Loading finished.
# 	Num samples: 1000
# 	Vocab file: /home/icarus/app/data/03_processed/tinytrainvocab.txt
# Initializing Embedding
# Initializing MPN
# Initializing JTNN
# Initializing Decoder
# Initializing JTMPN

# %%
MAX_EPOCH = 5
PRINT_ITER = 20

from tqdm import tqdm
from os import access, R_OK
from os.path import isdir
import sys

save_path = '/home/icarus/app/data/04_models'
assert isdir(save_path) and access(save_path, R_OK), \
       "File {} doesn't exist or isn't readable".format(save_path)

def train():
    dataset.training = True
    print("Loading data...")
    dataloader = DataLoader(
            dataset,
            batch_size=args.batch_size,
            shuffle=True,
            pin_memory=True,
            num_workers=10,
            collate_fn=JTNNCollator(vocab, True),
            drop_last=True,
            worker_init_fn=None)
    dataloader._use_shared_memory = False
    last_loss = sys.maxsize
    print("Beginning Training...")
    for epoch in range(MAX_EPOCH):
        word_acc,topo_acc,assm_acc,steo_acc = 0,0,0,0
        print("Epoch %d: " % epoch)

        for it, batch in tqdm(enumerate(dataloader),total=len(dataloader)):
            model.zero_grad()
            try:
                loss, kl_div, wacc, tacc, sacc, dacc = model(batch, args.beta)
            except:
                print([t.smiles for t in batch['mol_trees']])
                raise
            loss.backward()
            optimizer.step()

            word_acc += wacc
            topo_acc += tacc
            assm_acc += sacc
            steo_acc += dacc

            cur_loss = loss.item()
            
            if (it + 1) % PRINT_ITER == 0:
                word_acc = word_acc / PRINT_ITER * 100
                topo_acc = topo_acc / PRINT_ITER * 100
                assm_acc = assm_acc / PRINT_ITER * 100
                steo_acc = steo_acc / PRINT_ITER * 100

                print("KL: %.1f, Word: %.2f, Topo: %.2f, Assm: %.2f, Steo: %.2f, Loss: %.6f, Delta: %.6f" % (
                    kl_div, word_acc, topo_acc, assm_acc, steo_acc, cur_loss, last_loss - cur_loss))
                word_acc,topo_acc,assm_acc,steo_acc = 0,0,0,0
                sys.stdout.flush()

            if (it + 1) % 1500 == 0: #Fast annealing
                scheduler.step()
                print("learning rate: %.6f" % scheduler.get_lr()[0])
                
            if (it + 1) % 100 == 0:
                torch.save(model.state_dict(),
                            save_path + "/model.iter-%d-%d" % (epoch, it + 1))
                      
            #if last_loss - cur_loss < 1e-5:
            #    break
            last_loss = cur_loss

        scheduler.step()
        print("learning rate: %.6f" % scheduler.get_lr()[0])
        torch.save(model.state_dict(), save_path + "/model.iter-" + str(epoch))

# %%
import warnings; warnings.simplefilter('ignore')
train()
# Out:
# Loading data...
# Beginning Training...
# Epoch 0:
# 100%|██████████| 5/5 [00:51<00:00, 10.27s/it]
# learning rate: 0.000900
# Epoch 1:
# 100%|██████████| 5/5 [00:57<00:00, 11.50s/it]
# learning rate: 0.000810
# Epoch 2:
# 100%|██████████| 5/5 [00:56<00:00, 11.35s/it]
# learning rate: 0.000729
# Epoch 3:
# 100%|██████████| 5/5 [00:55<00:00, 11.17s/it]
# learning rate: 0.000656
# Epoch 4:
# 100%|██████████| 5/5 [00:53<00:00, 10.62s/it]
# learning rate: 0.000590

# %% [markdown]
# ## References
#
# <div class="cite2c-biblio"></div>

# %%
from utils.data import JTNNDataset
test_path=Path('/home/icarus/app/data/01_raw/moses/test.csv')
testset = JTNNDataset(data=test_path, 
                      vocab=vocab_path, training=False, intermediates=False)
def test():
    testset.training = False
    dataloader = DataLoader(
            testset,
            batch_size=1,
            shuffle=False,
            num_workers=0,
            collate_fn=JTNNCollator(vocab, False),
            drop_last=True,
            worker_init_fn=None)#worker_init_fn)

    # Just an example of molecule decoding; in reality you may want to sample
    # tree and molecule vectors.
    samples_path = '/home/icarus/app/data/05_model_output/tinytrain_sampled.csv'
    with open(samples_path, 'w+') as f:
        f.write('SMILES\n')
        
    n = 0
    for it, batch in enumerate(dataloader):
        if n > 1000:
            break
        try:
            #print(batch['mol_trees'])
            gt_smiles = batch['mol_trees'][0].smiles
            #print(gt_smiles)
            model.move_to_cuda(batch)
            _, tree_vec, mol_vec = model.encode(batch)
            tree_vec, mol_vec, _, _ = model.sample(tree_vec, mol_vec)
            smiles = model.decode(tree_vec, mol_vec)
            if(smiles == None):
                continue
            n+=1
            with open(samples_path, 'a') as f:
                f.write(f'{smiles}\n')
            print(f'{n}: {smiles}')
        except:
            continue
# Out:
# Loading data...
# <class 'pathlib.PosixPath'>
# Data[0]: SMILES
# Loading finished.
# 	Num samples: 176074
# 	Vocab file: /home/icarus/app/data/03_processed/tinytrainvocab.txt

# %%
torch.cuda.empty_cache()
test()
# Out:
# 1: CSCSC
# 2: SC(S)(S)Sc1ccc2c(ccc3ccccc32)c1
# 3: CS[C@H](S)NCNc1ccccc1
# 4: c1ccc(OCOc2cccc3ccccc23)cc1
# 5: OCO[C@H](Cc1cccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc12)c1ccc(O)c(O)c1
# 6: SCc1cc(-c2ccc3ccccc3c2)cc2ccccc12
# 7: OC(O)(O)Oc1cccc2ccccc12
# 8: CNCNCNc1ccccc1
# 9: COCOCOCO
# 10: CCCCCc1cc(C)c2ccccc2c1
# 11: NSCOCOCO
# 12: COCO[C@H](O)OC
# 13: COCO[C@H](O)OC
# 14: O=S
# 15: CC(C)(C)CC(C)(C)C
# 16: Sc1ccc2cc3ccccc3cc2c1
# 17: OCOc1ccc2cc3ccccc3cc2c1
# 18: COCOCOCO
# 19: CN(c1ccccc1)[C@H](N)S
# 20: SCNc1ccc2c(ccc3ccccc32)c1
# 21: SCOCOc1ccc2ccccc2c1
# 22: Cc1ccc2cc3ccccc3cc2c1
# 23: CC(C)c1cccc2c1ccc1ccccc12
# 24: CSCS
# 25: OC(O)OC(O)(O)O
# 26: CO[C@@H](O)Oc1ccc2ccccc2c1
# 27: CSCSc1ccc2cc3ccccc3cc2c1
# 28: CCCCc1ccc2cc3ccccc3cc2c1
# 29: C[SH](C)c1c2ccccc2cc2c1ccc1ccccc12
# 30: BrC(Br)c1ccc2cc3ccccc3cc2c1
# 31: COCOc1cccc2ccccc12
# 32: SCSc1cccc2c1ccc1c3ccccc3ccc21
# 33: COCOCOCO
# 34: CC(C)c1cccc2ccccc12
# 35: O=[SH]CNc1cccc2ccccc12
# 36: CSCS
# 37: c1ccc2c(c1)ccc1c2ccc2c1ccc1c3ccc4ccccc4c3ccc12
# 38: c1ccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc2c1
# 39: C[SH](C)Cc1cccc2ccccc12
# 40: OCOCOC(O)O
# 41: Cc1cccc2c1ccc1cc3ccccc3cc12
# 42: COCOCOCOCOCO
# 43: NC(Nc1ccccc1)Nc1ccccc1
# 44: Nc1ccc2cc3cc4ccccc4cc3cc2c1
# 45: CC(C)(S)c1ccc(O)c(O)c1O
# 46: SCc1c2ccccc2cc2cc3ccccc3cc12
# 47: CNCNCN(C)C
# 48: O=S
# 49: CCc1cc(C)c2ccccc2c1
# 50: Cc1cc2ccccc2cc1Cc1ccccc1
# 51: SC(S)c1cccc2cc3ccccc3cc12
# 52: OC(O)Oc1ccc2ccccc2c1
# 53: OCO[C@@H](O)Oc1ccc2cc3ccc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47ccccc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4c3cc2c1
# 54: SC(S)c1ccc2c(ccc3c4ccccc4ccc23)c1
# 55: c1ccc2cc(NCNCc3ccc4cc5ccc6ccccc6c5cc4c3)ccc2c1
# 56: c1ccc2c(CNc3cccc4c3ccc3c4ccc4c5ccccc5ccc43)cccc2c1
# 57: CSC(O)(O)OCO
# 58: SCSCNc1ccc2ccccc2c1
# 59: O=S(=O)=O
# 60: Cc1cc2ccccc2c2c1ccc1ccccc12
# 61: CSc1ccc2cc3ccccc3cc2c1
# 62: CN(c1cccc2c1ccc1ccccc12)c1cccc2c1ccc1c2ccc2c3ccc4ccccc4c3ccc12
# 63: CN(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 64: OC(O)O[C@H](O)Br
# 65: CN(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 66: COCOCOCO
# 67: CC(C)c1cccc2ccccc12
# 68: Sc1cccc2c1ccc1ccccc12
# 69: COCOc1ccc2ccccc2c1
# 70: COCOCO
# 71: CCCNc1ccc2ccccc2c1
# 72: CS(C)(C)c1cccc2c1ccc1ccccc12
# 73: O=C[SH](C=O)C=O
# 74: CSCc1ccc2cc3ccccc3cc2c1
# 75: COCOc1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21ccccc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12
# 76: CSc1ccc2cc3ccccc3cc2c1
# 77: SC(S)(S)Cc1cccc2ccccc12
# 78: CO[C@H](O)OCOCO
# 79: CCCc1ccc2cc3ccccc3cc2c1
# 80: CCCCCc1cc(O)cc(O)c1
# 81: CC(C)(C)c1cccc2c1ccc1c2ccc2c1ccc1c3ccc4c5ccccc5ccc4c3ccc21
# 82: c1ccc(Nc2ccc3ccccc3c2)cc1
# 83: c1ccc(OCOc2ccc3c(ccc4ccccc43)c2)cc1
# 84: CCC(=O)C(=O)c1ccccc1
# 85: C=O
# 86: CBr
# 87: COCOCOCOC
# 88: OCOC(O)(O)O
# 89: COCOCOCO
# 90: OCOCOc1ccc2ccccc2c1
# 91: SCNCNCNc1ccccc1
# 92: SCCCc1ccc2cc3cc4ccccc4cc3cc2c1
# 93: OCOC(O)(O)S
# 94: C1COCO1
# 95: CCc1cc2cc3ccccc3cc2c2ccccc12
# 96: C[S@@](=O)c1cccc2c1ccc1ccccc12
# 97: c1ccc2cc(NCNCNc3ccc4ccccc4c3)ccc2c1
# 98: CN(c1cccc2ccccc12)c1cccc2c1ccc1ccccc12
# 99: OC(O)OCOCS
# 100: CSc1ccc2cc3ccccc3cc2c1
# 101: COCOCOCO
# 102: OCOCO[C@H](O)Oc1ccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc2c1
# 103: CN([C@@H](N)O)C(N)(N)O
# 104: c1ccc(-c2ccc3cc4cc5ccccc5cc4cc3c2)cc1
# 105: COCOCOC
# 106: COCOC(O)O
# 107: CNCNc1ccc2ccccc2c1
# 108: OCOCOCOCO
# 109: COCOC
# 110: CSC(S)(S)S
# 111: CS[C@@H](N)NCN(C)C
# 112: COCOC(O)O
# 113: CSc1ccc2c(ccc3c4ccccc4ccc23)c1
# 114: CCCCc1ccc2ccccc2c1
# 115: CC(C)(C)Cc1cccc2c1ccc1c2ccc2c3ccccc3ccc21
# 116: O=CS(=O)(=O)c1c2ccccc2cc2ccccc12
# 117: Oc1ccc(O)c(SC(S)S)c1O
# 118: SCCCc1cccc2ccccc12
# 119: CCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 120: CSC[C@H](C)O
# 121: CS[C@@H](S)N(C)c1ccc2ccccc2c1
# 122: CCCCCc1ccc2ccccc2c1
# 123: N[C@H](Cc1cccc2ccccc12)Nc1ccccc1
# 124: O=S(=O)=O
# 125: OC(O)(O)OC(O)(O)O
# 126: SCSc1ccc2cc3ccccc3cc2c1
# 127: CO[C@](O)(c1ccccc1)c1ccc2ccccc2c1
# 128: SCNCNCNc1ccc2ccccc2c1
# 129: COC(O)(O)OC(O)O
# 130: Cc1cccc2c1ccc1c3ccccc3ccc21
# 131: O=S=O
# 132: CCCc1c(O)c(O)cc(O)c1O
# 133: Sc1cccc2cc3ccccc3cc12
# 134: O=S
# 135: C[SH](C)CNc1cccc2ccccc12
# 136: OCOC(O)(O)O
# 137: OCOc1ccc2cc3ccccc3cc2c1
# 138: O=S=O
# 139: CC(S)(S)c1c2ccccc2cc2ccccc12
# 140: OC(O)(O)O
# 141: c1ccc2cc(Nc3ccc4cc5cc6ccccc6cc5cc4c3)ccc2c1
# 142: Sc1cccc(Oc2ccc3cc4ccccc4cc3c2)c1
# 143: C[SH](C)c1c(O)c(O)c(O)c(O)c1O
# 144: CNCNc1cccc2ccccc12
# 145: CC(C)(C)C(C)(C)C
# 146: c1ccc2cc3cc4ccccc4cc3cc2c1
# 147: OC(O)Oc1ccc2cc3cc4ccccc4cc3cc2c1
# 148: COCOC(O)O
# 149: SCOCOc1ccc2ccccc2c1
# 150: SC(S)c1cccc2ccccc12
# 151: CO[C@H](O)OC(O)O
# 152: CCCCCc1ccc2ccccc2c1
# 153: COCOC
# 154: CSCSCNc1ccccc1
# 155: SCCCc1ccc2ccccc2c1
# 156: CNCNCNCN
# 157: CSCNc1ccc2c(ccc3ccccc32)c1
# 158: COCOCOCS
# 159: c1ccc2c(c1)ccc1c2ccc2c3ccc4ccccc4c3ccc12
# 160: CSC(C)(C)Cc1ccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc2c1
# 161: CN(CNc1cccc2cc3ccccc3cc12)c1cccc2ccccc12
# 162: COCOCOC
# 163: OC(O)OCOc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95ccccc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 164: CC(C)(C)c1cccc2ccccc12
# 165: COCOc1cccc2c1ccc1c2ccc2c1ccc1c3ccc4ccccc4c3ccc12
# 166: Cc1ccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc2c1
# 167: CN(c1ccccc1)c1ccc2ccccc2c1
# 168: CCc1cccc(-c2ccc3ccccc3c2)c1
# 169: c1ccc2cc(NCNc3ccc4cc5ccccc5cc4c3)ccc2c1
# 170: NSc1ccc2cc3ccc4ccccc4c3cc2c1
# 171: c1ccc(Cc2ccc3ccccc3c2)cc1
# 172: CN(c1cccc2ccccc12)C(N)(S)S
# 173: CC(S)(S)Cc1ccc2ccccc2c1
# 174: OC(O)OC(O)(O)O
# 175: COCOCO
# 176: CCc1cccc2c1ccc1c3ccccc3ccc21
# 177: NC(N)(S)Nc1ccc2cc3ccccc3cc2c1
# 178: SC(S)Cc1ccc2ccccc2c1
# 179: C[SH](C)c1cccc2c1ccc1ccccc12
# 180: C=O
# 181: CNCNC(S)S
# 182: CCCc1ccc2cc3ccccc3cc2c1
# 183: BrCBr
# 184: CO[C@@H](O)[SH](C)C
# 185: CN(c1cccc2ccccc12)c1cccc2cc3ccc4ccccc4c3cc12
# 186: c1ccc(Nc2cccc3ncc4c5ccncc5cnc4c23)cc1
# 187: OCOC(O)O
# 188: CO[C@](C)(CO)OCO
# 189: Sc1cccc2c1ccc1ccccc12
# 190: C[SH](C)C(O)(O)O
# 191: c1ccc2cc3cc4ccccc4cc3cc2c1
# 192: C[SH](C)c1cccc2c1ccc1c3ccccc3ccc21
# 193: O=S
# 194: C1=C[C@]23CCCN[C@@]2(CCNC3)c2ccc3ccccc3c21
# 195: CC[C@@](C)(S)SCS
# 196: CN(c1cccc2ccccc12)C(N)(S)S
# 197: c1ccc2c(c1)ccc1cc3cnccc3cc12
# 198: CCCCNCNc1ccc2cc3ccccc3cc2c1
# 199: C[C@H](CCS)c1ccccc1
# 200: CC(C)Nc1cccc2ccccc12
# 201: OCOCOC(O)O
# 202: C[SH](C)c1ccc2c(ccc3ccccc32)c1
# 203: CCC(C)(C)CC
# 204: CSCOCO
# 205: CO[C@@H](O)OCO
# 206: OCOCOCS
# 207: C=O
# 208: Cc1cc2ccccc2c2c1ccc1c3ccccc3ccc12
# 209: COCOCO
# 210: COC(O)(O)O
# 211: BrCCc1cc2cc3ccccc3cc2c2ccccc12
# 212: Cc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 213: OC(O)Oc1ccc2c(ccc3c4ccccc4ccc23)c1
# 214: COCOCOCO
# 215: OCCOCOC(O)O
# 216: COCO[C@H](O)OC
# 217: O=C(O)OC(O)(O)O
# 218: CNc1cccc2cc3ccccc3cc12
# 219: SC(S)Cc1ccc2ccccc2c1
# 220: CCCCCCc1ccc(C)cc1
# 221: CCCCc1ccc2cc3ccccc3cc2c1
# 222: CSc1cccc2c1ccc1ccccc12
# 223: C[C@H](OC(O)(O)O)c1cccc2ccccc12
# 224: COCOCOCO
# 225: COCSCSC
# 226: COCO[C@H](O)OC
# 227: SCCCc1ccc2c(ccc3c4ccccc4ccc23)c1
# 228: Cc1cccc([C@H](C)C(C)(C)C(C)(C)C(C)(C)c2cccc(C)c2)c1
# 229: O=C(SCS)Sc1ccc2cc3ccccc3cc2c1
# 230: OC(O)Oc1ccc2ccccc2c1
# 231: c1ccc2cc3c(C[C@@H]4CCCNC4)cccc3cc2c1
# 232: CCCc1ccc2ccccc2c1
# 233: CNCN[C@@H]1COCO1
# 234: CCc1ccc2cc3cc4cc5cc6c(ccc7ccccc76)cc5cc4cc3cc2c1
# 235: CSc1cccc2c1ccc1cc3ccccc3cc12
# 236: COC(OC)OCO
# 237: COCOCO
# 238: SC(S)Cc1ccc2ccccc2c1
# 239: COCSC
# 240: C[C@H](c1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16c(ccc%17ccccc%17%16)cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12)C(C)(C)S
# 241: Nc1ccc2cc3cc4ccccc4cc3cc2c1
# 242: c1ccc(NCNc2cccc3ccccc23)cc1
# 243: OCOC(Br)Br
# 244: C=O
# 245: COC(O)(O)O
# 246: CN(C)C(N)(N)N
# 247: CN(c1ccccc1)c1ccc2cc3cc4ccccc4cc3cc2c1
# 248: COC(O)(O)Oc1cccc2cc3cc4ccccc4cc3cc12
# 249: CN(c1cccc2ccccc12)C(N)(N)Nc1cccc2ccccc12
# 250: COCOCOCO
# 251: c1ccc(OCOc2ccc3ccccc3c2)cc1
# 252: OCOCOc1cccc2ccccc12
# 253: COCOCO
# 254: CSCSc1cc2ccccc2c2ccccc12
# 255: O=S=O
# 256: CSCCCc1ccc2ccccc2c1
# 257: CS[C@@H](S)OC(O)O
# 258: c1ccc(OCOc2cccc3c2ccc2c4ccccc4ccc32)cc1
# 259: c1ccc2c(c1)ccc1cc3ccc4ccccc4c3cc12
# 260: OCOCOCO
# 261: OC(O)OC(O)(O)OC(O)(O)O
# 262: O=[SH](=O)c1cc2cc3ccccc3cc2c2ccccc12
# 263: C[SH](C)c1ccc2cc3ccccc3cc2c1
# 264: CSCCCc1ccccc1
# 265: SC(S)Cc1ccc2ccccc2c1
# 266: CN(c1cccnc1)c1cccc2ccccc12
# 267: CSCNc1ccc2ccccc2c1
# 268: OC(O)(S)Oc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 269: COCO[C@@H](O)OC
# 270: c1ccc2c(c1)ccc1c3ccccc3ccc21
# 271: COCOc1c[nH]cn1
# 272: CCc1ccc2c(ccc3c4ccccc4ccc23)c1
# 273: OCOc1ccc2cc3ccccc3cc2c1
# 274: OC(O)OC(O)(O)O
# 275: COCOCOC
# 276: CC(C)Nc1cccc2ccccc12
# 277: O=C(S)Sc1cc2ccccc2c2ccccc12
# 278: O=S
# 279: OCOC1O[C@@H]2OCO[C@H]2O1
# 280: CCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 281: c1ccc(Nc2cccc3c2ccc2ccccc23)cc1
# 282: CCc1ccc2cc3ccccc3cc2c1
# 283: CSC(N)(N)Nc1ccc2ccccc2c1
# 284: CCCCc1ccc2cc3ccccc3cc2c1
# 285: O=[SH]CNc1cc2ccccc2c2ccccc12
# 286: CO[C@H](O)OCO
# 287: CN(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 288: CN(c1cccc2ccccc12)C(N)(N)NCNc1ccccc1Nc1cccc2c1ccc1ccccc12
# 289: COCOC(O)O
# 290: OCOCOc1ccc2ccccc2c1
# 291: CN(c1cccc2c1ccc1ccccc12)c1cccc2c1ccc1c2ccc2c3ccccc3ccc21
# 292: O=S=O
# 293: Sc1cccc2c1ccc1c3ccccc3ccc21
# 294: CS(C)(C)C
# 295: CCC(N)(N)NC
# 296: c1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 297: CCCCCc1ccc2ccccc2c1
# 298: NCN(c1ccccc1)c1ccc2ccccc2c1
# 299: O=S=O
# 300: OC(O)OC(O)(O)O
# 301: CO[C@@H](O)Oc1ccc2ccccc2c1
# 302: CCc1ccc2cc3cc4ccccc4cc3cc2c1
# 303: COCOCOCO
# 304: CN(CN(C)c1ccc2ccccc2c1)c1ccc2ccccc2c1
# 305: O=S
# 306: C[SH](C)(C=O)(C=O)c1ccc2ccccc2c1
# 307: SCNc1cccc2ccccc12
# 308: COCO[C@@H](O)OC
# 309: O=CSCc1cccc2c1ccc1ccccc12
# 310: SNSCc1ccc2cc3ccccc3cc2c1
# 311: COCO[C@@H](O)OC
# 312: CCCCCCCC
# 313: OCOCOCO
# 314: CSCNCNc1ccccc1
# 315: Cc1cccc2cc3cc4ccccc4cc3cc12
# 316: CN(c1cccc2ccccc12)c1cccc2cc3ccccc3cc12
# 317: BrCBr
# 318: OCOCOC(O)O
# 319: CCCCc1ccc2cc3ccccc3cc2c1
# 320: O=S=O
# 321: C[SH](C)c1ccc2cc3ccccc3cc2c1
# 322: c1ccc(NCNc2cccc3ccccc23)cc1
# 323: CS(C)(C)c1cccc2c1ccc1ccccc12
# 324: COCOCOCO
# 325: SCCCCc1ccc2ccccc2c1
# 326: OCOCOCO
# 327: c1ccc(Nc2ccc3cc4ccccc4cc3c2)cc1
# 328: CC(S)(S)c1cccc2cc3ccccc3cc12
# 329: CCCCc1ccc2cc3ccccc3cc2c1
# 330: OC(O)OC(O)(O)O
# 331: CO[C@H](O)OCO
# 332: CSc1cccc2c1ccc1c3ccccc3ccc21
# 333: COCOCOCOC
# 334: COCO[C@H](O)OCO
# 335: COC(O)OC
# 336: COC(C=O)(OC)c1ccc2ccccc2c1
# 337: CN(C)CN(C)c1ccccc1
# 338: CSCc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96cc%97cc%98ccccc%98cc%97cc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 339: COCOCOC
# 340: CN(c1ccccc1)C(N)(N)S
# 341: CCCCCc1ccccn1
# 342: OCOCOCO
# 343: CSCSc1ccc2cc3ccccc3cc2c1
# 344: COCOCOCO
# 345: COCOCOC
# 346: COC(O)(O)O
# 347: CO[C@H](O)Oc1ccc2ccccc2c1
# 348: c1ccc2c(c1)ccc1c(-c3ccnc4ncccc34)cccc12
# 349: OCOCOCOCS
# 350: CN(CNCNCNc1ccc(N)cc1)c1ccc(N)cc1
# 351: O=COCOC(O)O
# 352: CSc1cccc2c1ccc1ccccc12
# 353: CSC(N)(N)Nc1ccccc1
# 354: COC(O)(O)OC
# 355: c1ccc(NCNc2cccc3ccccc23)cc1
# 356: Sc1ccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc2c1
# 357: COCO[C@@H](O)OC
# 358: CC(S)(S)Cc1ccccc1
# 359: O=[SH](=O)CNc1ccc2ccccc2c1
# 360: CN(C)CNc1ccccc1
# 361: c1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 362: CCCC(=O)c1cccc2ccccc12
# 363: COC(O)(O)O
# 364: %10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccccc%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 365: CCCCCCc1ccc2cc3ccccc3cc2c1
# 366: CO[C@H](O)OC(O)(O)O
# 367: c1ccc2c(c1)ccc1c2ccc2c1ccc1c3ccc4ccccc4c3ccc12
# 368: SN(S)c1c2ccccc2cc2cc3ccccc3cc12
# 369: OCOCOc1ccc2ccccc2c1
# 370: SCNc1ccc2cc3ccccc3cc2c1
# 371: CNCNCSC=O
# 372: CCCNCNC(S)S
# 373: CSC[S@H](C=O)c1ccc2ccccc2c1
# 374: CC(C)Cc1ccc2ccccc2c1
# 375: O=S
# 376: CN(CNCc1ccc2ccccc2c1)c1ccccc1
# 377: OC(O)(O)Oc1cccc2c1ccc1ccccc12
# 378: CSc1ccc2c(ccc3ccccc32)c1
# 379: SN(S)Cc1cccc2ccccc12
# 380: c1ccc(Cc2cccc3c2ccc2c4ccccc4ccc32)cc1
# 381: CSCc1cc2ccccc2cc1C
# 382: CC(C)(C)Cc1cccc2ccccc12
# 383: COCOC(O)O
# 384: Sc1ccccc1-c1cccc2ccccc12
# 385: N[S@@](=O)Nc1cccc2ccccc12
# 386: OCOC(O)(O)O
# 387: SCSc1cccc2c1ccc1ccccc12
# 388: Cc1cccc2c1ccc1c3ccccc3ccc21
# 389: COCOc1ccc2cc3ccccc3cc2c1
# 390: CN(c1ccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc2c1)c1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28ccccc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 391: c1ccc2c(c1)ccc1c2ccc2ccc3c4ccncc4cnc3c21
# 392: CN(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 393: CSc1ccc2cc3ccccc3cc2c1
# 394: O=[SH]Cc1cccc2c1ccc1ccccc12
# 395: COCOCOCO
# 396: c1ccc(-c2cccc3c2ccc2ccccc23)cc1
# 397: CN(C)c1ccc2ccccc2c1
# 398: CO[C@H](O)OCO
# 399: CCCCCc1ccccc1
# 400: c1ccc2cc3c(ccc4cc5ccccc5cc43)cc2c1
# 401: CCCCC(C)C
# 402: CSc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 403: CN(CNc1cccc2ccccc12)c1ccccc1
# 404: COC(O)(O)OC(O)(O)OC
# 405: OCOCOCS
# 406: OC(O)(O)OC(O)(O)O
# 407: CSCSC
# 408: SCCCCc1ccccc1
# 409: CC[C@@](C)(N)NC
# 410: c1ccc2cc3cc4cc5cc6c(cc5cc4cc3cc2c1)CCCN6
# 411: c1ccc2cc3cc4cc5cc(Cc6ccc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21ccccc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7c6)ccc5cc4cc3cc2c1
# 412: OC(O)OCSNS
# 413: CSc1cccc2c1ccc1c3ccccc3ccc21
# 414: OCOC(O)OCO
# 415: CCCCCCc1ccc(C)cc1
# 416: c1ccc(-c2ccc3cc4cc5cc6ccccc6cc5cc4cc3c2)nc1
# 417: SCc1ccc2cc3cc4ccccc4cc3cc2c1
# 418: SCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 419: OC(O)(O)O
# 420: c1ccc(OCOc2cccc3ccccc23)cc1
# 421: C=O
# 422: NC(Nc1cccc2ccccc12)Nc1cccc2ccccc12
# 423: O=S
# 424: SCOc1cccc2c1ccc1ccccc12
# 425: OC(O)OC(O)(S)S
# 426: CCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 427: CC(C)C(C)(C)C
# 428: CSCS
# 429: CC(O)(O)C(C)(C)S
# 430: COCOC(O)O
# 431: CC[C@H](C)C(S)(S)S
# 432: CNc1cc2ccccc2c2cc3ccccc3cc12
# 433: CCCc1ccc2c(ccc3ccccc32)c1
# 434: O=S
# 435: CCCc1ccc2cc3ccccc3cc2c1
# 436: SCNCNc1ccc2ccccc2c1
# 437: C[SH](C)(=O)c1cc2ccccc2c2ccccc12
# 438: CSCNc1ccc2ccccc2c1
# 439: SC(S)Nc1ccc2cc3cc4ccccc4cc3cc2c1
# 440: N[C@H](Nc1ccccc1)Nc1ccc2ccccc2c1
# 441: OC(O)OC(S)(S)S
# 442: COCOCOCO
# 443: Sc1ccc2cc3ccccc3cc2c1
# 444: CN(c1ccccc1)[C@H](N)c1cccc2ccccc12
# 445: CO[C@@H](O)Oc1ccc2ccccc2c1
# 446: O=CSc1ccc2cc3ccccc3cc2c1
# 447: CNCNCNCNCNCNCNCNCNCNCNCNCNCNCNCNCNC
# 448: COCOCO
# 449: N[SH](N)c1ccc2c(ccc3c4ccccc4ccc23)c1
# 450: SC(S)(S)Sc1c2ccccc2cc2ccccc12
# 451: OCOC(O)(O)O
# 452: CN(c1cccc2ccccc12)[C@H](N)Nc1cccc2ccccc12
# 453: CCCCC(Br)Br
# 454: C[C@H](OC(O)O)c1ccc2ccccc2c1
# 455: SCc1c2ccccc2cc2c1ccc1ccccc12
# 456: CCCCCc1cccc2ccccc12
# 457: OCOC(O)(O)O
# 458: C=O
# 459: CO[C@H](O)OCO
# 460: CC(C)(C)%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccccc%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 461: CO[C@@H](O)Oc1ccc2cc3ccccc3cc2c1
# 462: CO[C@H](O)OCOCS
# 463: CSCNc1ccc2c(ccc3ccccc32)c1
# 464: SCCCc1ccc2c(ccc3c2ccc2c4ccccc4ccc23)c1
# 465: CNCN[C@@H](S)[SH](C)C
# 466: OCOCOCS
# 467: COC(O)(O)Oc1cccc2ccccc12
# 468: CSc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 469: CN(CNCN)c1ccc2ccccc2c1
# 470: CC(C)C(C)(C)C
# 471: Cc1cccc2c1ccc1c3ccccc3ccc21
# 472: OCOC(O)(Br)Br
# 473: O=C(O)Oc1cccc2c1ccc1ccccc12
# 474: COCOCOC
# 475: c1cc2c(cn1)cnc1ccncc12
# 476: OC(O)(S)Oc1ccc2cc3ccccc3cc2c1
# 477: SC(S)Nc1cccc2c1ccc1ccccc12
# 478: OC(O)OC(O)(O)O
# 479: NCNCNc1ccc2ccccc2c1
# 480: CNc1ccc2c(ccc3ccccc32)c1
# 481: O=S(=O)=O
# 482: COCO[C@@H](O)[SH]=O
# 483: CO[C@H](O)Oc1ccc2c(ccc3c2ccc2c4ccccc4ccc23)c1
# 484: CCCCc1ccc2cc3ccccc3cc2c1
# 485: CSCSc1c(O)cc2ccccc2c1O
# 486: SCCc1ccc2cc3ccccc3cc2c1
# 487: CS[C@@H](S)Oc1cccc2cc3ccccc3cc12
# 488: CC(C)(C)c1cccc2ccccc12
# 489: CCCc1cc(C)c2ccccc2c1
# 490: O=[SH]CNCNc1ccccc1
# 491: O=S=O
# 492: Sc1cccc2c1ccc1c3ccccc3ccc21
# 493: OC(O)(O)OCOc1cccc2c1ccc1ccccc12
# 494: c1ccc(-c2ccc3cc4ccccc4cc3c2)cc1
# 495: SCNc1cc2ccccc2c2ccccc12
# 496: C=O
# 497: C[SH](C)c1cccc2c1ccc1c3ccccc3ccc21
# 498: CNc1ccc2cc3ccccc3cc2c1
# 499: CS[C@H](N)Nc1cccc2ccccc12
# 500: SN(S)Cc1ccc2cc3ccccc3cc2c1
# 501: CSCNc1cc2ccccc2c2ccccc12
# 502: COCO[C@@H](O)OCO
# 503: C[C@@H](Nc1cccc2cc3ccc4ccccc4c3cc12)c1cccc2cc3cc4cc5cc6cc7ccc8ccccc8c7cc6cc5cc4cc3cc12
# 504: CSCNc1ccc2c(ccc3ccccc32)c1
# 505: CC(C)%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccccc%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 506: c1ccc2cc3cc4c(ccc5c(NCNc6cccc7c6ccc6cc8ccc9c(ccc%10c9ccc9c%10ccc%10c9ccc9c%11ccc%12c%13ccc%14cc%15cc%16ccccc%16cc%15cc%14c%13ccc%12c%11ccc9%10)c8cc67)cccc54)cc3cc2c1
# 507: CC(C)(C)c1cccc2c1ccc1ccccc12
# 508: SCOCOc1ccc2cc3ccccc3cc2c1
# 509: COC(O)(O)OCO
# 510: CC(C)(C)c1ccc2cc3cc4c(ccc5ccccc54)cc3cc2c1
# 511: OC(O)(O)Oc1cccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c3ccc4c5ccc6c7ccccc7ccc6c5ccc4c3ccc21
# 512: COCOCOCO
# 513: OCOCO
# 514: CCCCCCC
# 515: CNCNc1ccc2ccccc2c1
# 516: CSc1cccc2c1ccc1ccccc12
# 517: CSCOCOc1cccc2c1ccc1c2ccc2c3ccccc3ccc21
# 518: OCOCOCOCO
# 519: COCOCO
# 520: CC(C)(C)NCNc1ccccc1
# 521: CN(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 522: CSCNc1cccc2ccccc12
# 523: Cc1ccc2ccccc2c1Cc1ccccc1
# 524: COCOCOc1cccc2cc3ccccc3cc12
# 525: SNCNc1ccc2ccccc2c1
# 526: OC(O)(O)OC(O)(O)O
# 527: COC(O)(O)O
# 528: CCCC(C)(C)CC
# 529: CN(CC(O)(O)O)c1ccc2ccccc2c1
# 530: COC(OC)OCO
# 531: N[C@H](Nc1ccccc1)Nc1ccc2ccccc2c1
# 532: C[C@@H](S)Cc1ccc2ccccc2c1
# 533: C[SH](C)c1ccc2cc3ccccc3cc2c1
# 534: O=S
# 535: COc1ccc2cc3ccccc3cc2c1
# 536: COCOCOC
# 537: O=CNc1cc2ccccc2c2c1ccc1ccccc12
# 538: COCOCOC
# 539: CO[C@H](O)OCS
# 540: CO[C@@H](O)Oc1ccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc2c1
# 541: OCOC(O)(O)O
# 542: COCOCOCO
# 543: SCCc1cccc2c1ccc1ccccc12
# 544: CO[C@H](O)OC(O)O
# 545: CO[C@H](O)OCOc1cccc2cc3cc4cc5cc6cc7cc8c(ccc9ccccc98)cc7cc6cc5cc4cc3cc12
# 546: CNCNc1cccc2ccccc12
# 547: O=CBr
# 548: SCNCNCNc1ccccc1
# 549: CC(C)Cc1cccc2ccccc12
# 550: COCOCOCO
# 551: SCCCc1cccc2c1ccc1ccccc12
# 552: COC(O)(O)OC
# 553: Cc1cccc2cc3cc4cc5ccc6ccccc6c5cc4cc3cc12
# 554: CO[C@@H](O)OC(O)(O)O
# 555: CCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 556: COCOCOCO
# 557: SC(S)NCNc1ccc2ccccc2c1
# 558: OCOCOCOCO
# 559: Sc1ccc2cc3cc4ccccc4cc3cc2c1
# 560: C=O
# 561: c1ccc2cc3cc4cc5cc6cc(Nc7ccc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50ccccc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8c7)ccc6cc5cc4cc3cc2c1
# 562: SCSc1ccc2cc3ccccc3cc2c1
# 563: CN(C)C(C)(N)N
# 564: SCCCCCCc1ccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc2c1
# 565: OCOCOC(O)O
# 566: CC(C)(S)c1ccc2ccccc2c1
# 567: Brc1cccc2c1ccc1ccccc12
# 568: O=[SH]CNc1cc2ccccc2c2ccccc12
# 569: COCOCOCO
# 570: O=CS
# 571: CSCc1cccc2cc3ccccc3cc12
# 572: c1ccc(NCNc2ccc3ccccc3c2)cc1
# 573: CSCc1ccc2c(ccc3ccccc32)c1
# 574: OC(O)OCOc1ccc2cc3ccccc3cc2c1
# 575: CSCNc1c2ccccc2cc2ccccc12
# 576: SCc1ccc2cc3cc4ccccc4cc3cc2c1
# 577: SC(S)(S)c1cccc2c1ccc1ccccc12
# 578: CSCc1cccc2c1ccc1ccccc12
# 579: CSC(C)(C)C(C)C
# 580: CCc1ccc2cc3cc4ccccc4cc3cc2c1
# 581: Cc1cccc2c1ccc1c2ccc2c3ccc4ccccc4c3ccc12
# 582: C[S@@H](C=O)c1ccc2cc3ccccc3cc2c1
# 583: C[SH](C)C
# 584: C1COC2(O1)OCCO2
# 585: O=CO[C@H](O)Oc1cccc2ccccc12
# 586: c1ccc(-c2ccc3cc4cc5ccccc5cc4cc3c2)cc1
# 587: C=O
# 588: C[SH](C)c1cccc2c1ccc1ccccc12
# 589: C[SH](C)(C)(C)c1ccc2ccccc2c1
# 590: C[C@H](c1cccc2ccccc12)[SH](C)C
# 591: CC(C)Cc1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96ccccc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12
# 592: CC(C)(Cc1cccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c3ccc4c5ccc6c7ccc8c9ccccc9ccc8c7ccc6c5ccc4c3ccc21)c1cccc2c1ccc1c2ccc2c1ccc1c3ccc4ccccc4c3ccc12
# 593: COC(O)(O)OCO
# 594: OCOc1cccc2c1ccc1c3ccccc3ccc21
# 595: SC(S)c1cccc2cc3ccccc3cc12
# 596: SCNCc1ccc2ccccc2c1
# 597: SCSCc1ccc2ccccc2c1
# 598: FCF
# 599: CN(CNc1ccc2ccccc2c1)c1ccc2cc3ccccc3cc2c1
# 600: c1ccc2c(c1)ccc1cc(CCCCc3ccc4c(ccc5c6ccccc6ccc45)c3)ccc12
# 601: CO[C@H](O)Oc1cccc2ccccc12
# 602: c1ccc2c(Nc3cccc4c3ccc3c4ccc4c5ccccc5ccc43)cccc2c1
# 603: CCc1cccc2c1ccc1c3ccccc3ccc21
# 604: CCCCCCC
# 605: CSCc1ccc2ccccc2c1
# 606: CCc1c2ccccc2cc2cc3ccccc3cc12
# 607: CO[C@@H](O)OCO
# 608: SCSc1cccc2c1ccc1ccccc12
# 609: COC(O)(O)OCO
# 610: CO[C@@H](O)Oc1cccc2ccccc12
# 611: COC(O)(O)OCO
# 612: CC(C)CCCc1cccc(O)c1
# 613: NCNc1ccc2c(ccc3ccccc32)c1
# 614: CSc1cc2ccc3ccccc3c2c2ccccc12
# 615: COCO[C@H](O)Oc1cccc2cc3cc4ccccc4cc3cc12
# 616: COC(O)(O)OC
# 617: c1ccc(Cc2cccc3ccccc23)cc1
# 618: Sc1ccc2cc3cc4ccccc4cc3cc2c1
# 619: %10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccc%50c%51ccccc%51ccc%50c%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 620: CCCCCc1cccc2ccccc12
# 621: COCOC(O)O
# 622: OCOC(O)OCO
# 623: CSc1ccc2cc3ccccc3cc2c1
# 624: CSC(O)(O)O
# 625: OCOC(O)(O)O
# 626: CO[C@@H](O)OCOCS
# 627: Sc1ccc2cc3cc4ccccc4cc3cc2c1
# 628: OCOC(O)(O)O
# 629: OCOC(O)(S)S
# 630: CSCNCNc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95ccccc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 631: CC(C)Cc1cccc2ccccc12
# 632: SCCCc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21ccccc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 633: CCCCCC(C)(C)c1cccc(C)c1C
# 634: CN(CF)c1ccc2ccccc2c1
# 635: C=O
# 636: CC(C)Nc1cccc2ccccc12
# 637: CN[C@](C)(c1ccccc1)N1CCCCC1
# 638: Cc1ccccc1CC(C)(C)C
# 639: CCCCCCc1ccc2ccccc2c1
# 640: Sc1ccc2cc3cc4ccccc4cc3cc2c1
# 641: COCOC(Br)Br
# 642: CC(C)(C)c1ccc2ccccc2c1
# 643: COC(O)(O)OC(O)O
# 644: C=O
# 645: CN(CN)c1ccc2ccccc2c1
# 646: COCSCSC
# 647: COCOCOC
# 648: OCOCOCO
# 649: SC(S)SCc1ccc2ccccc2c1
# 650: C=O
# 651: CSCOCOCO
# 652: Cc1ccc2cc3cc4ccccc4cc3cc2c1
# 653: CNC(N)(N)Nc1ccccc1
# 654: CC(C)c1cccc2c1ccc1ccccc12
# 655: CSc1c(O)c(O)cc(O)c1O
# 656: CC(C)%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccccc%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 657: O=COCOc1ccc2cc3ccccc3cc2c1
# 658: CCCCc1ccc2ccccc2c1
# 659: SCSc1ccc2cc3cc4ccccc4cc3cc2c1
# 660: SCNCNc1ccccc1
# 661: COC(O)(OC)OC
# 662: CO[C@@H](O)OCO
# 663: CC(C)C(C)(Br)Br
# 664: COCOCOCO
# 665: Sc1ccc2cc3cc4ccccc4cc3cc2c1
# 666: OC(O)(O)OC(O)(O)O
# 667: OCOC(S)S
# 668: CCCc1ccc2cc3ccccc3cc2c1
# 669: SCSc1ccc2c(ccc3ccccc32)c1
# 670: NCNc1cc2ccccc2c2ccccc12
# 671: SNSc1cccc2c1ccc1ccccc12
# 672: COCO[C@H](O)OC
# 673: OCOCOCOCO
# 674: CN(c1ccccc1)[C@H](N)S
# 675: CC(C)(C)c1cccc2c1ccc1c3ccccc3ccc21
# 676: CC(C)(C)C(C)(C)S
# 677: c1ccc(-c2ccc3c(ccc4cc5ccccc5cc43)c2)cc1
# 678: SCCc1cccc(-c2ccc3ccccc3c2)c1
# 679: OC(O)(S)OCOc1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11ccc%12ccccc%12c%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12
# 680: SCCCc1cccc2ccccc12
# 681: C[C@@](O)(CO)OC(O)O
# 682: OC(O)OC(O)(O)O
# 683: COC(O)(O)OC
# 684: COCOCOC
# 685: CN(CNc1cccc2ccccc12)c1ccccc1
# 686: COCOCOCS
# 687: CC(C)(C)%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccccc%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 688: COC(O)(S)S
# 689: SCSc1ccc2ccccc2c1
# 690: c1ccc2c(c1)ccc1c3ccccc3ccc21
# 691: OCOCOCO
# 692: COCOCOC
# 693: c1ccc2cc3cc(NCCCc4ccc5cc6cc7cc8ccccc8cc7cc6cc5c4)ccc3cc2c1
# 694: COCO[C@@H](O)OC
# 695: CSCOCOCO
# 696: C=O
# 697: COCOCOC
# 698: COCOCOCO
# 699: COC(O)(Br)Br
# 700: COC(OC)OCO
# 701: OCOCOc1ccncc1
# 702: COC(O)(O)OC(O)O
# 703: CCc1cccc(-c2ccc3ccccc3c2)c1
# 704: COC(O)(O)O
# 705: OCOCOc1ccc2ccccc2c1
# 706: CCNCNc1ccc2ccccc2c1
# 707: C=O
# 708: O=S(=O)=O
# 709: Sc1ccc2cc3ccc4ccccc4c3cc2c1
# 710: CCCCc1cccc2c1ccc1ccccc12
# 711: COCOC(O)O
# 712: COCOCO
# 713: O=S
# 714: CSC(O)(O)OCO
# 715: CO[C@@H](S)SC
# 716: CSCNc1cccc2c1ccc1ccccc12
# 717: c1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 718: SC(S)c1cccc2c1ccc1ccccc12
# 719: BrC(Br)(Br)Cc1ccc2ccccc2c1
# 720: O=CSC=O
# 721: COCOC
# 722: CN(c1ccccc1)c1cccc2c1ccc1ccccc12
# 723: COCOCOCOCO
# 724: CC(C)(S)Cc1ccccc1
# 725: CSc1ccc2cc3ccccc3cc2c1
# 726: COC(C)(S)OC
# 727: CN(c1cccnc1)c1ccc2ccccc2c1
# 728: COC(OC)OCS
# 729: C[SH](C)c1cccc2c1ccc1ccccc12
# 730: CCCCCO
# 731: c1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 732: ClCN(Cc1ccc2c(ccc3ccccc32)c1)c1ccccc1
# 733: CC(C)(C)c1ccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc2c1
# 734: COCOCO
# 735: O=S(=O)=O
# 736: Sc1cccc2c1ccc1ccccc12
# 737: c1ccc2c(c1)ccc1c2ccc2c1ccc1c3ccc4ccccc4c3ccc12
# 738: OCO[C@H](O)OC(O)O
# 739: CSCNc1ccc2ccccc2c1
# 740: COCOCOCO
# 741: SC(S)(S)S
# 742: CCCCCCCC
# 743: COCOCOCS
# 744: COCOCOCO
# 745: COCOCOC
# 746: c1ccc2c(c1)ccc1c2ccc2c3ccc4ccccc4c3ccc12
# 747: CN(CN)c1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96cc%97ccccc%97cc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12
# 748: C[C@H](c1cccc2c1ccc1ccccc12)[SH](N)N
# 749: COCOCOCO
# 750: SCCCCc1ccc2cc3ccccc3cc2c1
# 751: CNC(N)(N)[SH](C)C
# 752: CC(C)OC(O)(O)S
# 753: O=CS
# 754: CCCc1cccc2c1ccc1c3ccccc3ccc21
# 755: COCOCOc1ccc2ccccc2c1
# 756: CN(c1ccccc1)c1ccc2ccccc2c1
# 757: SCc1cccc(-c2ccc3ccccc3c2)c1
# 758: CNCNc1ccc2ccccc2c1
# 759: OC(O)OC(O)O
# 760: CC(C)c1cccc2c1ccc1ccccc12
# 761: O=S(=O)=O
# 762: OC(O)OC(O)O
# 763: Cc1ccc2ccccc2c1CC(C)(C)C
# 764: CCCCCCCCC
# 765: CSCSc1ccc2c(ccc3ccccc32)c1
# 766: COCOCOCO
# 767: CCc1ccc2cc3cc4ccccc4cc3cc2c1
# 768: C[SH](C)[C@@H](S)Nc1cccc2ccccc12
# 769: C[SH](C)c1ccc2c(ccc3ccccc32)c1
# 770: CSCc1cc2ccccc2c2c1ccc1ccccc12
# 771: CC(C)(N)Nc1ccc2ccccc2c1
# 772: c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21
# 773: C=O
# 774: CC(C)C(C)(C)NCS
# 775: O=S(=O)=O
# 776: CC(C)C(C)(S)S
# 777: O=S(=O)=O
# 778: CC(C)c1cccc2c1ccc1ccccc12
# 779: Sc1cccc2c1ccc1c3ccccc3ccc21
# 780: COCOCOc1ccc2ccccc2c1
# 781: SCNCNc1ccc2ccccc2c1
# 782: CCCCc1cccc2ccccc12
# 783: CCc1ccc2cc3cc4ccccc4cc3cc2c1
# 784: OCOC(O)(O)O
# 785: OCOc1cccc2cc3ccccc3cc12
# 786: c1ccc2c(NCNc3ccc4c(ccc5ccccc54)c3)cccc2c1
# 787: O=CSC(=O)S
# 788: COCO[C@H](O)OC
# 789: CO[C@H](O)OCOCBr
# 790: CSc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 791: OCOc1ccc2cc3ccccc3cc2c1
# 792: CN(c1ccccc1)c1ccnc2cccnc12
# 793: CC(C)CC(O)(O)O
# 794: OC(O)OC(O)(S)S
# 795: Cc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 796: CSCNc1ccc2ccccc2c1
# 797: CCCCCc1cccc2c1ccc1ccccc12
# 798: OC(O)OC(O)(O)O
# 799: O=S
# 800: c1ccc(CNc2ccc3ccccc3c2)cc1
# 801: c1ccc(Cc2ccc3ccccc3c2)nc1
# 802: SNCNc1cccc2ccccc12
# 803: SCNc1ccc2cc3ccccc3cc2c1
# 804: SCNCNc1ccc2ccccc2c1
# 805: CCCc1cccc2c1ccc1ccccc12
# 806: OCOC(O)(O)S
# 807: COCO[C@H](O)Oc1ccc2cc3ccccc3cc2c1
# 808: CSc1cccc2c1ccc1ccccc12
# 809: c1ccc(Nc2ccc3ccccc3c2)cc1
# 810: C[C@H](S)c1ccc2ccccc2c1
# 811: OC(O)Oc1ccc2cc3ccccc3cc2c1
# 812: CSCOCOCO
# 813: SCNCNCNc1ccccc1
# 814: CSCNCNc1cccc2ccccc12
# 815: CNCNc1cccc2ccccc12
# 816: CC(C)(C)Cc1cccc2ccccc12
# 817: O=C(S)SCS
# 818: OCOc1ccc2ccccc2c1
# 819: CCCCc1cccc2cc3cc4cc5cc6cc7cc8ccccc8cc7cc6cc5cc4cc3cc12
# 820: SCc1ccc2cc3ccccc3cc2c1
# 821: BrCNCCCc1ccc2ccccc2c1
# 822: c1ccc2cc3cc4cc(NCNc5ccc6cc7cc8cc9cc%10cc%11cc%12cc%13ccccc%13cc%12cc%11cc%10cc9cc8cc7cc6c5)ccc4cc3cc2c1
# 823: CN(CN)C[SH](C)C
# 824: CSCNc1cccc2c1ccc1ccccc12
# 825: %10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccc%48c%49ccc%50ccccc%50c%49ccc%48c%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc12
# 826: C=O
# 827: C[SH](C)c1ccc2cc3cc4ccccc4cc3cc2c1
# 828: SNSCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 829: SCNCNc1cccc2ccccc12
# 830: c1ccc2cc(Cc3cc4ncc5ncccc5c4cn3)ccc2c1
# 831: COCOC
# 832: SCCCc1ccc2ccccc2c1
# 833: SCOc1ccc2c(%10ccc%11c%12ccc%13c%14ccc%15c%16ccc%17c%18ccc%19c%20ccc%21c%22ccc%23c%24ccc%25c%26ccc%27c%28ccc%29c%30ccc%31c%32ccc%33c%34ccc%35c%36ccc%37c%38ccc%39c%40ccc%41c%42ccc%43c%44ccc%45c%46ccc%47c%48ccc%49c%50ccc%51ccccc%51c%50ccc%49c%48ccc%47c%46ccc%45c%44ccc%43c%42ccc%41c%40ccc%39c%38ccc%37c%36ccc%35c%34ccc%33c%32ccc%31c%30ccc%29c%28ccc%27c%26ccc%25c%24ccc%23c%22ccc%21c%20ccc%19c%18ccc%17c%16ccc%15c%14ccc%13c%12ccc%11c%10ccc9c8ccc7c6ccc5c4ccc32)c1
# 834: CNc1cccc2cc3ccccc3cc12
# 835: CCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 836: COCO[C@@H](O)OC
# 837: COCOC(O)O
# 838: COCOCOC
# 839: c1ccc(CCCc2ccc3ccccc3c2)nc1
# 840: C[SH](C)C(=O)S
# 841: O=CS(=O)(=O)C=O
# 842: COC(O)(O)OCO
# 843: COC(O)O
# 844: CCc1cccc2c1ccc1c3ccccc3ccc21
# 845: C=O
# 846: Cc1cccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96cc%97cc%98cc%99ccc%(100)ccccc%(100)c%99cc%98cc%97cc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc12
# 847: Cc1cc2ccccc2cc1CCS
# 848: COCOCO
# 849: Oc1ccc2c(ccc3c2ccc2c4ccccc4ccc23)c1
# 850: CSC(N)(N)Nc1ccccc1
# 851: CCCC(=O)c1ccc2ccccc2c1
# 852: C[C@H](S)c1cccc2c1ccc1ccccc12
# 853: SNc1cccc2c1ccc1c3ccccc3ccc21
# 854: OC(O)OC(O)(O)O
# 855: OCOCOCO
# 856: c1ccc2cc3cc4cc5c(cc4cc3cc2c1)NC[C@@H]1CCNC[C@@H]51
# 857: CNCNCNCN
# 858: SC(S)NCc1ccc2ccccc2c1
# 859: C[C@@H](O)C(C)(C)C(C)(C)O
# 860: NC(N)(Nc1ccccc1)c1cccc2ccccc12
# 861: Sc1ccc2c(ccc3c4ccccc4ccc23)c1
# 862: CCCc1ccc2cc3ccccc3cc2c1
# 863: O=S
# 864: CO[C@@H](O)OCO
# 865: c1ccc(CCc2cccc3c2ccc2ccccc23)cc1
# 866: O=S(=O)=O
# 867: COCOC
# 868: CN(CNc1ccc2cc3ccccc3cc2c1)c1ccc2ccccc2c1
# 869: c1ccc(Nc2cccc3cc4ccccc4cc23)cc1
# 870: C[C@H](O)C(O)(O)OC(O)O
# 871: COCOCO
# 872: OC(O)OC(O)O
# 873: COCOCOCO
# 874: c1ccc(NCNc2ccccc2)cc1
# 875: CCCc1cccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c1ccc1c2ccc2c3ccc4c5ccc6c7ccc8c9ccc%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28ccccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc12
# 876: SCN(CNc1ccc2cc3ccccc3cc2c1)c1ccc2ccccc2c1
# 877: COCO[C@H](O)OC
# 878: CC(C)(c1cccc2ccccc12)[SH](=O)=O
# 879: CCc1c2ccccc2cc2c1ccc1ccccc12
# 880: SCSc1ccc2cc3ccccc3cc2c1
# 881: CC(C)C(C)(C)C
# 882: CC(C)C(=O)c1cccc2cc3ccccc3cc12
# 883: O=CBr
# 884: OCOc1ccc2cc3ccccc3cc2c1
# 885: FCOc1ccc2cc3ccccc3cc2c1
# 886: COCOCOCO
# 887: O=S
# 888: O=C(Br)c1ccc2c(ccc3ccccc32)c1
# 889: COCOCOC
# 890: SC(S)Cc1ccc2cc3ccccc3cc2c1
# 891: CCCc1ccc2cc3cc4ccccc4cc3cc2c1
# 892: Cc1ccc([C@@H](C)S(C)(C)C)c2ccccc12
# 893: CCCc1ccc2ccccc2c1
# 894: c1ccc(NCNc2ccc3ccccc3c2)cc1
# 895: Sc1ccccc1-c1cccc2ccccc12
# 896: CCCc1ccc2cc3ccccc3cc2c1
# 897: OCOCOCS
# 898: COC(O)(O)OC
# 899: OCOC(O)OCO
# 900: CC(C)(C)C(C)(C=O)C=O
# 901: CCc1cccc2c1ccc1c3ccccc3ccc21
# 902: C[C@@H](O)OCOC(O)O
# 903: COC(O)(O)O
# 904: COC(O)(O)O
# 905: CO[C@H](O)OCO
# 906: SCCc1ccc2c(ccc3c2ccc2c4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96ccc%97ccccc%97c%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4ccc23)c1
# 907: O=CSC=O
# 908: C=O
# 909: OC(O)Oc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96cc%97ccccc%97cc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 910: CN(C)c1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96cc%97cc%98ccccc%98cc%97cc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 911: COC(O)(O)%10c%11ccc%12c%13ccc%14c%15ccc%16c%17ccc%18c%19ccc%20c%21ccc%22c%23ccc%24c%25ccc%26c%27ccc%28c%29ccc%30c%31ccc%32c%33ccc%34c%35ccc%36c%37ccc%38c%39ccc%40c%41ccc%42c%43ccc%44c%45ccc%46c%47ccccc%47ccc%46c%45ccc%44c%43ccc%42c%41ccc%40c%39ccc%38c%37ccc%36c%35ccc%34c%33ccc%32c%31ccc%30c%29ccc%28c%27ccc%26c%25ccc%24c%23ccc%22c%21ccc%20c%19ccc%18c%17ccc%16c%15ccc%14c%13ccc%12c%11ccc%10c9ccc8c7ccc6c5ccc4c3ccc21
# 912: SCCc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 913: CCc1cccc2c1ccc1c2ccc2c3ccc4ccccc4c3ccc12
# 914: O=CSC=O
# 915: C[SH](C)CCc1ccc2ccccc2c1
# 916: BrC(Br)c1ccc2ccccc2c1
# 917: CO[C@@H](O)Oc1cccc2c1ccc1ccccc12
# 918: OC(O)OC(O)O
# 919: COCOCOC
# 920: c1ccc(OCOc2cccc3cc4ccccc4cc23)cc1
# 921: Cc1cc(CSCS)c2ccccc2c1
# 922: CN(CNCNc1ccc2ccccc2c1)c1ccc2ccccc2c1
# 923: COC(O)(O)OC
# 924: CO[C@H](O)Oc1cccc2c1ccc1ccccc12
# 925: CC(C)C(C)(C)S
# 926: OCOCBr
# 927: CO[C@@H](O)OCSC
# 928: SCOc1ccc2cc3ccccc3cc2c1
# 929: SCc1ccc2cc3ccccc3cc2c1
# 930: CS(C)(C)c1cccc2cc3ccccc3cc12
# 931: SC(S)Cc1ccc2ccccc2c1
# 932: COCOCOCOC
# 933: OCOC(S)S
# 934: COC(=O)OC(O)(O)OC
# 935: CCCCC(S)S
# 936: SCSc1cccc2cc3ccccc3cc12
# 937: CC(C)CCc1ccc2ccccc2c1
# 938: CNCNc1ccc2ccccc2c1
# 939: COCO[C@H](NC(O)O)N[C@H](O)N(CO)C(O)O
# 940: COC(O)(S)S
# 941: CC(C)C(C)(S)S
# 942: COCOCOCO
# 943: CS[C@H](S)Nc1cccc2ccccc12
# 944: CSc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 945: Oc1cc(CCS)cc(O)c1O
# 946: CCCCc1cccc2c1ccc1c3ccccc3ccc21
# 947: OCOCOCSCS
# 948: SCS[C@@H](S)Nc1ccc2ccccc2c1
# 949: SC(S)N(c1ccccc1)c1ccc2cc3ccccc3cc2c1
# 950: COC(O)(O)OCO
# 951: OC(O)OC(O)(O)O
# 952: SCCCCc1ccc2ccccc2c1
# 953: CCCCCCC
# 954: COCOCOC
# 955: C[SH](C)CNc1cccc2ccccc12
# 956: CO[C@@H](O)O[C@@H](C)c1cccc2ccccc12
# 957: C=O
# 958: SCc1ccc2cc3ccccc3cc2c1
# 959: CN(CNc1ccc2ccccc2c1)c1ccc2ccccc2c1
# 960: COCOCOCOCOC
# 961: CC(C)(C)Cc1cccc2ccccc12
# 962: SC(S)(S)Nc1ccc2c(ccc3ccccc32)c1
# 963: OCO[C@H](O)Oc1ccc2c(ccc3ccccc32)c1
# 964: CSc1ccc2cc3cc4ccccc4cc3cc2c1
# 965: CCCCCC
# 966: SCc1ccc2ccccc2c1
# 967: COC(O)(O)CC(=O)O
# 968: COCO[C@H](O)c1ccc2ccccc2c1
# 969: CC[C@H](C)CCCS
# 970: CCCCCCCCCC
# 971: SC(S)SCc1ccc2cc3ccccc3cc2c1
# 972: c1ccc(-c2ccc3cc4cc5ccccc5cc4cc3c2)cc1
# 973: C[S@H](CS)c1ccc2cc3ccccc3cc2c1
# 974: CCCc1cccc2c1ccc1c3cc4c(ccc5cc6cc7cc8cc9cc%10cc%11cc%12ccc%13cc%14ccc%15c%16ccccc%16ccc%15c%14cc%13c%12cc%11cc%10cc9cc8cc7cc6cc54)cc3ccc21
# 975: COCOCOC
# 976: OCO[C@@H](O)Oc1ccc2ccccc2c1
# 977: CC(C)c1cc2ccccc2c2ccccc12
# 978: Oc1cccc([C@H](O)OC(O)(O)O)c1
# 979: COCOCO
# 980: SCNc1ccc2cc3cc4ccccc4cc3cc2c1
# 981: O=S
# 982: COCOc1ccc2ccccc2c1
# 983: CC(C)C(C)(C)S
# 984: CS[C@@H](S)c1cc2ccccc2c2ccccc12
# 985: SCNCNCNc1ccccc1
# 986: CSCOCOCO
# 987: OCOCOCO
# 988: COC(O)(O)O
# 989: CO[C@@H](O)OCBr
# 990: O=S=O
# 991: COCOCOC
# 992: O=C(S)Sc1ccc2cc3ccccc3cc2c1
# 993: CN(CNc1ccc2ccccc2c1)c1ccc2cc3ccccc3cc2c1
# 994: CCc1ccc2cc3cc4ccccc4cc3cc2c1
# 995: CC(C)(C)Cc1ccc2cc3cc4cc5cc6cc7cc8cc9cc%10cc%11cc%12cc%13cc%14cc%15cc%16cc%17cc%18cc%19cc%20cc%21cc%22cc%23cc%24cc%25cc%26cc%27cc%28cc%29cc%30cc%31cc%32cc%33cc%34cc%35cc%36cc%37cc%38cc%39cc%40cc%41cc%42cc%43cc%44cc%45cc%46cc%47cc%48cc%49cc%50cc%51cc%52cc%53cc%54cc%55cc%56cc%57cc%58cc%59cc%60cc%61cc%62cc%63cc%64cc%65cc%66cc%67cc%68cc%69cc%70cc%71cc%72cc%73cc%74cc%75cc%76cc%77cc%78cc%79cc%80cc%81cc%82cc%83cc%84cc%85cc%86cc%87cc%88cc%89cc%90cc%91cc%92cc%93cc%94cc%95cc%96ccccc%96cc%95cc%94cc%93cc%92cc%91cc%90cc%89cc%88cc%87cc%86cc%85cc%84cc%83cc%82cc%81cc%80cc%79cc%78cc%77cc%76cc%75cc%74cc%73cc%72cc%71cc%70cc%69cc%68cc%67cc%66cc%65cc%64cc%63cc%62cc%61cc%60cc%59cc%58cc%57cc%56cc%55cc%54cc%53cc%52cc%51cc%50cc%49cc%48cc%47cc%46cc%45cc%44cc%43cc%42cc%41cc%40cc%39cc%38cc%37cc%36cc%35cc%34cc%33cc%32cc%31cc%30cc%29cc%28cc%27cc%26cc%25cc%24cc%23cc%22cc%21cc%20cc%19cc%18cc%17cc%16cc%15cc%14cc%13cc%12cc%11cc%10cc9cc8cc7cc6cc5cc4cc3cc2c1
# 996: c1ccc2cc3cc4cc5cc6ccccc6cc5cc4cc3cc2c1
# 997: c1cc2ccncc2cn1
# 998: COCOCOCO
# 999: Cc1ccc2cc3cc4cc5ccccc5cc4cc3cc2c1
# 1000: COCOCOCO
# 1001: OCO[C@@H](O)OCBr
